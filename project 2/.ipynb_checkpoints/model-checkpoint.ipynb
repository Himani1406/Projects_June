# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Heart_Disease_data.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# #### Attribute Information:
#
# age
#
# sex
#
# cp = chest pain type (4 values)
#
# trestbps = resting blood pressure
#
# chol = serum cholestoral in mg/dl
#
# fbs = fasting blood sugar > 120 mg/dl
#
# restecg = resting electrocardiographic results (values 0,1,2)
#
# thalach = maximum heart rate achieved
#
# exang = exercise induced angina
#
# oldpeak = oldpeak = ST depression induced by exercise relative to rest
#
# slope = the slope of the peak exercise ST segment
#
# ca = number of major vessels (0-3) colored by flourosopy
#
# thal: 0 = normal; 1 = fixed defect; 2 = reversable defect
#
# target = Heart Disease (0=no; 1=yes)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# #### Percentage of people having Heart Disease

# %%
num = df.groupby('target').size()
num
# Out:
# target
# 0    499
# 1    526
# dtype: int64

# %%
# pie chart
plt.figure(figsize=(10,7))
plt.pie(num, labels=['Absence', 'Presence'], autopct='%0.0f%%')
plt.title('Heart Disease Population %', fontsize=20)

plt.show()

# %% [markdown]
# People having Heart Disease are more than the people who do not have.

# %%
#Countplot Creation of Population Age using MatplotLib and Seaborn

plt.figure(figsize=(25,17))
sns.countplot(x='age', data=df)
plt.title('Population Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.show()

# %% [markdown]
# #### Statistical Analysis of Age groups present

# %%
# Minimum age
MinAge = df['age'].min()
print("Minimun Age = ", MinAge)

# Maximum age
MaxAge = df['age'].max()
print("Maximum Age = ", MaxAge)

# Mean age
MeanAge = df['age'].mean()
print("Mean Age = ",MeanAge)
# Out:
# Minimun Age =  29
# Maximum Age =  77
# Mean Age =  54.43414634146342

# %% [markdown]
# #### Categorizing the age data

# %%
Young_Ages=df[(df['age']>=29) & (df['age']<40)]
Middle_Ages=df[(df['age']>=40) & (df['age']<55)]
Elderly_Ages=df[(df['age']>55)]
print('Young Ages =',len(Young_Ages))
print('Middle Ages =',len(Middle_Ages))
print('Elderly Ages =',len(Elderly_Ages))
# Out:
# Young Ages = 57
# Middle Ages = 419
# Elderly Ages = 519

# %%
# Plot Creation of Age Category 

sns.barplot(x=['Young_Ages','Middle_Ages','Elderly_Ages'], y=[len(Young_Ages), len(Middle_Ages), len(Elderly_Ages)], palette='YlGn_r')
plt.title('Age Category', fontsize=17)
plt.xlabel('Age Range', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.show()

# %% [markdown]
# #### Categorizing Age with Gender

# %%
#Converting Age Data into Categorical Data

def age_range(row):
    if row>=29 and row<40:
        return 'Young Age'
    elif row>=40 and row<55:
        return 'Middle Age'
    elif row>55:
        return 'Elder Age'

# %%
#Applying converted data into our dataset with new column - Age_Range
df2 = df
df2['Age_Range']=df2['age'].apply(age_range)
df2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target   Age_Range
# 0   2     3       0  Middle Age
# 1   0     3       0  Middle Age
# 2   0     3       0   Elder Age
# 3   1     3       0   Elder Age
# 4   3     2       0   Elder Age

# %%
#Swarm Plot Creation of Gender Based Age Category using MatplotLib and Seaborn

# sex 0= Female ; 1= Male


plt.figure(figsize=(10,7))
sns.swarmplot(x='Age_Range', y='age', hue='sex', data=df2, order=['Young Age','Middle Age','Elder Age'], palette='Oranges_r')
plt.title('Gender Based Age Category', fontsize=17)
plt.xlabel('Age Category', fontsize=15)
plt.ylabel('Age', fontsize=15)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 13.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 23.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Interpretation : Number of Males are more in Middle Age as well as in Elder Age category.

# %%
#Count Plot Creation of Heart Disease Based On Age Category using MatplotLib and Seaborn

# converting numerical data into categorical data:
def heart_disease(row):
    if row==0:
        return 'Absence'
    elif row==1:
        return 'Presence'
df2['Heart_Disease']=df2['target'].apply(heart_disease)

#plotting the data:

plt.figure(figsize=(7,5))
hue_order=['Young Age', 'Middle Age', 'Elder Age']
sns.countplot(x='Heart_Disease', hue='Age_Range', data=df2, order=['Presence','Absence'], hue_order=hue_order, palette='Pastel1')
plt.title('Heart Disease Based On Age Category', fontsize=17)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %%
def gender(row):
    if row==1:
        return 'Male'
    elif row==0:
        return 'Female'

df2['sex1']=df2['sex'].apply(gender)





plt.figure(figsize=(7,5))
sns.countplot(x=df2['Heart_Disease'], hue='sex1', data=df2, palette='BuGn_r')
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.legend(labels=['Male','Female'])
plt.title('Heart Disease Based on Gender',fontsize=17)
plt.show()

# %% [markdown]
# Interpretation = Males are more prone to Heart Diseases.

# %% [markdown]
# ### Visualization of different parameters

# %% [markdown]
# ### 1. Chest Pain

# %%
# Data of Chest pain experienced 

sns.countplot(x=df2['Heart_Disease'], hue='cp', data=df2, order=['Presence','Absence'])
plt.title('Chest Pain Experienced', fontsize=15)
plt.xlabel('Heart Disease', fontsize=13)
plt.ylabel('Count', fontsize=13)
plt.legend(labels=['Typical Angina', 'Atypical Angina', 'Non-Anginal pain', 'Asymptomatic'])
plt.show()

# %%
# Chest pain based on gender

sns.countplot(x=df2['sex1'], hue='cp', data=df2)
plt.title('Chest Pain Based On Gender', fontsize=17)
plt.xlabel('Sex', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %%
# Chest Pain Based On Age Category 

sns.countplot(x=df2['Age_Range'], hue='cp', data=df2, order=['Young Age', 'Middle Age', 'Elder Age'], palette='BrBG')
plt.title('Chest Pain Based On Age Category', fontsize=17)
plt.xlabel('Age Category', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
# Interpretation = There is very high number of Typical Angina Pain in Elderly age Category

# %% [markdown]
# ### 2. Blood Pressure

# %%
# Bar Plot of Person's Resting Blood Pressure

sns.barplot(x='sex1', y='trestbps', data=df2, palette='plasma')
plt.title("Blood Pressure", fontsize=17)
plt.xlabel('Sex',fontsize=15)
plt.ylabel("Person's Resting Blood Pressure (mm Hg)", fontsize=12)
plt.show()

# %% [markdown]
# Interpretation = Blood Pressure is almost equal in Males and Females.

# %%
#Bar Plot Creation of Blood Pressure VS Heart Disease 

sns.barplot(x='Heart_Disease', y='trestbps', data=df2, palette='tab20b_r')
plt.title('Blood Pressure VS Heart Disease', fontsize=17)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Blood Pressure', fontsize=15)
plt.show()

# %%
#Line Plot Creation of Blood Pressure VS Age 

sns.lineplot(x='age', y='trestbps', data=df2, color='r')
plt.title('Blood Pressure VS Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Blood Pressure', fontsize=15)
plt.show()

# %% [markdown]
# Interpretation = Blood Pressure increases between age of 50 to 60 and somehow continue the pattern till 70

# %% [markdown]
# ### 3.Cholesterol level

# %%
sns.barplot(x='sex1', y='chol', data=df2, palette='turbo')
plt.title("Cholestrol Level Based On Gender", fontsize=17)
plt.xlabel('Sex',fontsize=15)
plt.ylabel("Cholestrol", fontsize=15)
plt.show()

# %% [markdown]
# Interpretation = Females have a higher level of Cholestrol compared to Males.

# %%
# Relationship between Choelstrol Level and presence of Heart Disease

sns.barplot(x='Heart_Disease', y='chol', data=df2, palette='ocean_r')
plt.title('Cholestrol VS Heart Disease', fontsize=17)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Cholestrol', fontsize=15)
plt.show()

# %%
#Line Plot Creation of Cholestrol VS Age 

sns.lineplot(x='age', y='chol', data=df2, color='b')
plt.title('Cholestrol VS Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Cholestrol', fontsize=15)
plt.show()

# %% [markdown]
# Interpretation = Cholestrol Increasing in the age group of 50-60

# %% [markdown]
# ### 4. ST Depression

# %%
#Line Plot Creation of ST Depression VS Age 

sns.lineplot(x='age', y='oldpeak', data=df2, color='g')
plt.title('ST Depression VS Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('ST depression', fontsize=15)
plt.show()

# %% [markdown]
# Interpretation = ST depression mostly increases between the age group of 30-40 and 50-60.

# %%
#Bar Plot Creation of ST depression VS Heart Disease 

sns.barplot(x='sex1', y='oldpeak', data=df2, palette='twilight_r')
plt.title('ST depression VS Heart Disease', fontsize=17)
plt.xlabel('Sex', fontsize=15)
plt.ylabel('ST depression', fontsize=15)
plt.show()

# %% [markdown]
# Interpretation = More Males are prone to ST depression as compare to females

# %% [markdown]
# ### 5.Exercise induced Angina

# %%
#Bar Plot Creation of Exercise induced Angina VS Heart Disease 

sns.barplot(x='Heart_Disease', y='exang', data=df2, palette='viridis')
plt.title('Exercise With Angina VS Heart Disease', fontsize=17)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Exercise With Angina', fontsize=15)
plt.show()

# %%
#Bar Plot Creation of Exercise With Angina VS Gender 

sns.barplot(x='sex1', y='exang', data=df2, palette='binary_r')
plt.title('Exercise With Angina VS Gender', fontsize=17)
plt.xlabel('Sex', fontsize=15)
plt.ylabel('Exercise With Angina', fontsize=15)
plt.show()

# %%
df = df2.drop(['Heart_Disease','sex1','Age_Range'], axis=1)
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# ## Splitting test and training set

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...

# %%
sns.heatmap(df.corr(), annot =True)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
from sklearn.model_selection import train_test_split

x = df.drop(["target"], axis=1)
y = df["target"]

# Splitting data set - 25% test dataset and 75% 

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state=5)

print("x_train :",x_train.shape)
print("x_test :",x_test.shape)
print("y_train :",y_train.shape)
print("y_test :",y_test.shape)
# Out:
# x_train : (768, 13)
# x_test : (257, 13)
# y_train : (768,)
# y_test : (257,)

# %%
print(x_train)
print(y_train)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 593    63    0   0       108   269    0        1      169      1      1.8
# 846    35    0   0       138   183    0        1      182      0      1.4
# 388    64    1   0       120   246    0        0       96      1      2.2
# 344    41    1   1       120   157    0        1      182      0      0.0
# 178    44    1   0       110   197    0        0      177      0      0.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 998    42    1   0       136   315    0        1      125      1      1.8
# 701    35    1   0       120   198    0        1      130      1      1.6
# 1007   56    1   3       120   193    0        0      162      0      1.9
# 206    59    1   2       126   218    1        1      134      0      2.2
# 867    41    1   1       110   235    0        1      153      0      0.0
#
#       slope  ca  thal
# 593       1   2     2
# 846       2   0     2
# ...

# %% [markdown]
# ## Random Forest Algorithm

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 11)
model.fit(x_train,y_train)
rf_predict = model.predict(x_test)
rf_predict
# Out:
# array([0.90909091, 0.        , 1.        , 0.        , 0.90909091,
#        1.        , 1.        , 1.        , 0.90909091, 1.        ,
#        1.        , 0.90909091, 0.90909091, 1.        , 0.        ,
#        1.        , 0.        , 1.        , 1.        , 0.        ,
#        1.        , 0.81818182, 0.        , 0.        , 1.        ,
#        0.        , 0.90909091, 0.90909091, 0.        , 1.        ,
#        0.        , 0.        , 0.90909091, 0.        , 0.        ,
#        1.        , 0.27272727, 1.        , 0.        , 0.        ,
#        1.        , 0.        , 0.        , 0.        , 1.        ,
#        0.        , 0.63636364, 1.        , 1.        , 0.        ,
#        0.        , 0.81818182, 0.        , 0.        , 0.09090909,
#        0.90909091, 1.        , 0.90909091, 0.90909091, 1.        ,
#        0.90909091, 0.72727273, 0.        , 0.        , 0.90909091,
#        0.        , 0.        , 0.18181818, 0.        , 0.90909091,
# ...

# %%
# Calculating R2 score

from sklearn.metrics import r2_score
r1 = r2_score(y_test,rf_predict)
print("R2 score : ",r1)
# Out:
# R2 score :  0.9718194135265613

# %%
ax = sns.distplot(y_test, hist = False, color = "r", label = "Actual value ")
sns.distplot(rf_predict, hist = False, color = "b", label = "Predicted Values", ax = ax)
plt.title('Random Forest Regression')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13620\551929062.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(y_test, hist = False, color = "r", label = "Actual value ")
# C:\Users\HP\AppData\Local\Temp\ipykernel_13620\551929062.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# #### Trying Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lnr_predict = model.predict(x_test)

# %%
r = r2_score(y_test,lnr_predict)
print("R2 score : ",r)
# Out:
# R2 score :  0.50713672463675

# %%
plt.scatter(y_test,lnr_predict)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Linear Regression')
# Out:
# Text(0.5, 1.0, 'Linear Regression')

# %% [markdown]
# #### Trying Logistic Regression

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression


scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
log_predict = model.predict(X_test)

# %%
r = r2_score(y_test,log_predict)
print("R2 score : ",r)
# Out:
# R2 score :  0.40833636253483585

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)



plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, s=50, edgecolor='k', label='Actual')
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train_pred, s=20, edgecolor='k', marker='x', label='Predicted')
plt.title('Training Set: Actual vs Predicted')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13620\2262908202.py:10: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train_pred, s=20, edgecolor='k', marker='x', label='Predicted')
